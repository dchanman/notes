# %% [markdown]
# # Assignment 2
#
# ## CRC
# * Parts 3 and 4 will take very little time in the assignment
# * 32-bit "hash"
# * Just traverse the whole space and try to find a pair
# *

# %%
stringToCrack = "..."

# Determine frequency analysis of characters
freq = dict()
digramFreq = dict()
trigramFreq = dict()

for a in stringToCrack:
    if a not in freq:
        freq[a] = 1
    else:
        freq[a] = freq[a] + 1

for i in range(0, len(stringToCrack) - 1):
    a = stringToCrack[i] + stringToCrack[i+1]
    if a not in digramFreq:
        digramFreq[a] = 1
    else:
        digramFreq[a] = digramFreq[a] + 1

for i in range(0, len(stringToCrack) - 2):
    a = stringToCrack[i] + stringToCrack[i+1] + stringToCrack[i+2]
    if a not in trigramFreq:
        trigramFreq[a] = 1
    else:
        trigramFreq[a] = trigramFreq[a] + 1

sortedHistogram = [(a, freq[a]) for a in freq]
sortedDigrams = [(a, digramFreq[a]) for a in digramFreq]
sortedTrigrams = [(a, trigramFreq[a]) for a in trigramFreq]

sortedHistogram.sort(key = lambda a: a[1], reverse = True)
sortedDigrams.sort(key = lambda a: a[1], reverse = True)
sortedTrigrams.sort(key = lambda a: a[1], reverse = True)

print(sortedHistogram)
print(sortedDigrams)
print(sortedTrigrams)

letterFrequencyOrder = "etaoinsrhldcumfpgwybvkxjqz"
        
cipher = {
"F": "e",
"O": "t",
"C": "l",
"I": "s",
"H": "d",
"N": "h",
"B": "o",
"K": "r",
"P": "h",
"Y": "a",
"T": "i",
"R": "c",
"U": "u",
"J": "m",
"A": "f",
"W": "p",
"M": "g",
"V": "w",
"D": "y",
"Q": "b",
"G": "v",
"S": "k",
}

decipher = ""
for a in stringToCrack:
    if a in cipher:
        decipher += cipher[a]
    else:
        decipher += "_"



for a in sortedHistogram:
    print("{}: {}".format(a[0], a[1]))

for a in sortedDigrams:
    print("{}: {}".format(a[0], a[1]))

for i in range(0, len(sortedHistogram)):
    print('"{}": "{}",'.format(sortedHistogram[i][0], letterFrequencyOrder[i]))
    
print()
print(decipher)
# Out:
# [('F', 67), ('O', 55), ('C', 52), ('I', 49), ('H', 43), ('N', 42), ('B', 37), ('K', 34), ('P', 33), ('Y', 31), ('T', 27), ('R', 23), ('U', 19), ('J', 16), ('A', 16), ('W', 15), ('M', 13), ('V', 9), ('D', 8), ('Q', 7), ('G', 7), ('S', 1)]
# [('NF', 21), ('IN', 21), ('FH', 14), ('KC', 12), ('RO', 11), ('OI', 11), ('CP', 11), ('CT', 10), ('KK', 9), ('OK', 9), ('OU', 9), ('BY', 8), ('PH', 8), ('NC', 8), ('YF', 8), ('CI', 8), ('BP', 7), ('HO', 7), ('NB', 7), ('YA', 6), ('FP', 6), ('AB', 6), ('FM', 6), ('IO', 6), ('JB', 6), ('HH', 6), ('IB', 6), ('FC', 6), ('AO', 6), ('OJ', 5), ('YH', 5), ('FJ', 5), ('OC', 5), ('UY', 5), ('KF', 5), ('BK', 5), ('WO', 5), ('YY', 5), ('HY', 5), ('PI', 5), ('RV', 4), ('FR', 4),
CQB', 1), ('NAB', 1), ('GOP', 1), ('ITF', 1), ('OIW', 1), ('PPF', 1), ('HCI', 1), ('AOC', 1), ('UIR', 1), ('BRV', 1), ('FJW', 1), ('RVH', 1), ('FAQ', 1), ('HFC', 1), ('BDN', 1), ('FDF', 1), ('PFB', 1), ('FIU', 1), ('KCT', 1), ('TTI', 1), ('BKA', 1), ('FYT', 1), ('UGC', 1), ('MBT', 1), ('GIF', 1), ('YHH', 1), ('TCQ', 1), ('VMB', 1), ('SFB', 1), ('FJK', 1), ('OJN', 1), ('JNF', 1), ('PHD', 1), ('IBK', 1), ('JCJ', 1), ('ITD', 1), ('NFR', 1), ('FRN', 1), ('NBR', 1), ('GOR', 1), ('NFI', 1), ('KRO', 1), ('NOG', 1), ('FKC', 1), ('OJA', 1), ('FBW', 1), ('RJB', 1), ('TRO', 1), ('QJB', 1), ('BKI', 1), ('PIB', 1), ('IIF', 1), ('CTN', 1), ('HFD', 1), ('INJ', 1), ('FJR', 1), ('PMN', 1), ('CTA', 1), ('YFI', 1), ('QYU', 1), ('TYO', 1), ('CRR', 1), ('TNF', 1), ('YYN', 1), ('FHU', 1), ('MNB', 1), ('CQO', 1), ('NFN', 1), ('UGO', 1), ('OMO', 1), ('YUR', 1), ('NJF', 1), ('HOU', 1), ('FWU', 1), ('DAB', 1), ('CAB', 1), ('HPO', 1), ('FII', 1), ('RNA', 1), ('FGI', 1), ('RFN', 1), ('WFC', 1), ('HGB', 1), ('WIN', 1), ('FFK', 1), ('ORV', 1), ('OCM', 1), ('RCK', 1), ('NCS', 1), ('NFC', 1), ('YHY', 1), ('NFW', 1), ('KRN', 1), ('GFR', 1), ('DIN', 1), ('MNC', 1), ('AOI', 1), ('FFP', 1), ('FPH', 1), ('CSF', 1), ('HUG', 1), ('UIN', 1), ('HRJ', 1), ('IWU', 1), ('YHV', 1), ('FNF', 1), ('BFH', 1), ('ITB', 1), ('PHA', 1), ('IOI', 1), ('QOU', 1), ('KDC', 1), ('HNF', 1), ('TTR', 1), ('AOH', 1), ('ICT', 1), ('CPO', 1), ('HFH', 1), ('OIC', 1), ('PWI', 1), ('AOR', 1), ('BTW', 1), ('CKO', 1), ('TDO', 1), ('OGF', 1), ('FCT', 1), ('IOD', 1), ('HOP', 1), ('YFM', 1), ('CHN', 1), ('RFG', 1), ('YNB', 1), ('IUP', 1), ('JBF', 1), ('UIO', 1), ('HPF', 1), ('WCB', 1), ('FHA', 1), ('BKR', 1), ('QBP', 1), ('DCB', 1), (' ...
# F: 67
# O: 55
# C: 52
# I: 49
# H: 43
# N: 42
# B: 37
# K: 34
# P: 33
# Y: 31
# T: 27
# R: 23
# U: 19
# J: 16
# A: 16
# W: 15
# M: 13
# V: 9
# D: 8
# Q: 7
# G: 7
# S: 1
# NF: 21
# IN: 21
# FH: 14
# KC: 12
# RO: 11
# OI: 11
# CP: 11
# CT: 10
# KK: 9
# OK: 9
# OU: 9
# BY: 8
# PH: 8
# NC: 8
